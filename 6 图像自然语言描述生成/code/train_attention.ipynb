# %%
# !pip config set global.index-url https://pypi.tuna.tsinghua.edu.cn/simple
# !pip install -U nltk
# Out:
# Writing to /home/mw/.config/pip/pip.conf
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (3.8.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from nltk) (4.63.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.7/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from click->nltk) (4.11.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.7.0)

# %%
# !mkdir /home/mw/project/coco2014
# !ln -s /home/mw/input/020614521/test2014/test2014 /home/mw/project/coco2014
# !ln -s /home/mw/input/02066579/val2014/* /home/mw/project/coco2014
# !ln -s /home/mw/input/020628093/train2014-1/train2014-1 /home/mw/project/coco2014
# !ln -s /home/mw/input/020631458/train2014-2/train2014-2 /home/mw/project/coco2014
# Out:
# mkdir: cannot create directory ‘/home/mw/project/coco2014’: File exists
# ln: failed to create symbolic link '/home/mw/project/coco2014/test2014': File exists
# ln: failed to create symbolic link '/home/mw/project/coco2014/val2014': File exists
# ln: failed to create symbolic link '/home/mw/project/coco2014/train2014-1': File exists
# ln: failed to create symbolic link '/home/mw/project/coco2014/train2014-2': File exists

# %%
import torch
import torchvision.transforms as transforms
import torch.nn as nn
import torch.backends.cudnn as cudnn
from models import Encoder, DecoderWithRNN, DecoderWithAttention
from datasets import *
from solver import *

# %%
cfg = {
    # Data parameters
    'data_folder' : '/home/mw/work/work_dir',  
    'data_name' : 'coco_5_cap_per_img_5_min_word_freq',  # base name shared by data files
    # Model parameters
    'embed_dim' : 512,  # dimension of word embeddings
    'attention_dim' : 512,  # dimension of attention linear layers
    'decoder_dim' : 512,  # dimension of decoder RNN
    'dropout' : 0.5,
    'device' : torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),  # sets device for model and PyTorch tensors
    # Training parameters
    'start_epoch' : 0,
    'epochs' : 10,  # number of epochs to train for (if early stopping is not triggered)
    'epochs_since_improvement' : 0,  # keeps track of number of epochs since there's been an improvement in validation BLEU
    'batch_size' : 32,
    'workers' : 1,  # for data-loading; right now, only 1 works with h5py
    'encoder_lr' : 1e-4,  # learning rate for encoder if fine-tuning
    'decoder_lr' : 4e-4,  # learning rate for decoder
    'grad_clip' : 5.,  # clip gradients at an absolute value of
    'alpha_c' : 1.,  # regularization parameter for 'doubly stochastic attention', as in the paper
    'best_bleu4' : 0.,  # BLEU-4 score right now
    'print_freq' : 100,  # print training/validation stats every __ batches
    'fine_tune_encoder' : False,  # fine-tune encoder or not
    'checkpoint' : None,  # path to checkpoint, None if none
    'attention' : True, # train decoder with attention or not
}
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# %%
word_map_file = os.path.join(cfg['data_folder'], 'WORDMAP_' + cfg['data_name'] + '.json')
with open(word_map_file, 'r') as j:
    word_map = json.load(j)
cfg['vocab_size'] = len(word_map)

# %%
os.environ['TORCH_HOME'] = '/home/mw/work/work_dir/coco2014'

# %%
if cfg['checkpoint'] is None:
    encoder = Encoder()
    encoder.fine_tune(cfg['fine_tune_encoder'])
    encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
                                         lr=cfg['encoder_lr']) if cfg['fine_tune_encoder'] else None
    if not cfg['attention']:
        decoder = DecoderWithRNN(cfg)
    else:
        decoder = DecoderWithAttention(cfg)
    decoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, decoder.parameters()),
                                         lr=cfg['decoder_lr'])
else:
    checkpoint = torch.load(cfg['checkpoint'])
    cfg['start_epoch'] = checkpoint['epoch'] + 1
    cfg['epochs_since_improvement'] = checkpoint['epochs_since_improvement']
    cfg['best_bleu4'] = checkpoint['bleu-4']
    encoder = checkpoint['encoder']
    encoder_optimizer = checkpoint['encoder_optimizer']
    decoder = checkpoint['decoder']
    decoder_optimizer = checkpoint['decoder_optimizer']
    if cfg['fine_tune_encoder'] is True and encoder_optimizer is None:
        encoder.fine_tune(cfg['fine_tune_encoder'])
        encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
                                             lr=cfg['encoder_lr'])

# %%
# Move to GPU, if available
decoder = decoder.to(cfg['device'])
encoder = encoder.to(cfg['device'])

# %%
# Loss function
criterion = nn.CrossEntropyLoss().to(cfg['device'])

# %%
# Custom dataloaders
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
train_loader = torch.utils.data.DataLoader(
    CaptionDataset(cfg['data_folder'], cfg['data_name'], 'TRAIN', transform=transforms.Compose([normalize])),
    batch_size=cfg['batch_size'], shuffle=True, num_workers=cfg['workers'], pin_memory=True)
val_loader = torch.utils.data.DataLoader(
    CaptionDataset(cfg['data_folder'], cfg['data_name'], 'VAL', transform=transforms.Compose([normalize])),
    batch_size=cfg['batch_size'], shuffle=True, num_workers=cfg['workers'], pin_memory=True)

# %%
# Epochs
for epoch in range(cfg['start_epoch'], cfg['epochs']):

    # Decay learning rate if there is no improvement for 8 consecutive epochs, and terminate training after 20
    if cfg['epochs_since_improvement'] == 20:
        break
    if cfg['epochs_since_improvement'] > 0 and cfg['epochs_since_improvement'] % 8 == 0:
        adjust_learning_rate(decoder_optimizer, 0.8)
        if cfg['fine_tune_encoder']:
            adjust_learning_rate(encoder_optimizer, 0.8)

    # One epoch's training
    train(train_loader=train_loader,
          encoder=encoder,
          decoder=decoder,
          criterion=criterion,
          encoder_optimizer=encoder_optimizer,
          decoder_optimizer=decoder_optimizer,
          epoch=epoch,
          cfg=cfg)
    
    # One epoch's validation
    recent_bleu4 = validate(val_loader=val_loader,
                            encoder=encoder,
                            decoder=decoder,
                            criterion=criterion,
                            word_map=word_map,
                            cfg=cfg)

    # Check if there was an improvement
    is_best = recent_bleu4 > cfg['best_bleu4']
    cfg['best_bleu4'] = max(recent_bleu4, cfg['best_bleu4'])
    if not is_best:
        cfg['epochs_since_improvement'] += 1
        print("\nEpochs since last improvement: %d\n" % (cfg['epochs_since_improvement'],))
    else:
        cfg['epochs_since_improvement'] = 0

    # Save checkpoint
    save_checkpoint(cfg['data_name'], epoch, cfg['epochs_since_improvement'], encoder, decoder, encoder_optimizer,
                    decoder_optimizer, recent_bleu4, is_best)
# Out:
# /home/mw/project/models.py:203: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   alpha = F.softmax(e)
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: [0][0/17702]	Batch Time 1.410 (1.410)	Data Load Time 0.265 (0.265)	Loss 10.1272 (10.1272)	Top-5 Accuracy 0.000 (0.000)
# Epoch: [0][100/17702]	Batch Time 0.372 (0.357)	Data Load Time 0.000 (0.003)	Loss 6.0618 (6.6365)	Top-5 Accuracy 38.315 (34.350)
# Epoch: [0][200/17702]	Batch Time 0.383 (0.357)	Data Load Time 0.000 (0.002)	Loss 5.2919 (6.2037)	Top-5 Accuracy 46.809 (37.952)
# Epoch: [0][300/17702]	Batch Time 0.349 (0.356)	Data Load Time 0.000 (0.001)	Loss 5.1142 (5.9215)	Top-5 Accuracy 50.549 (41.230)
# Epoch: [0][400/17702]	Batch Time 0.356 (0.356)	Data Load Time 0.000 (0.001)	Loss 4.4512 (5.7220)	Top-5 Accuracy 58.747 (43.567)
# Epoch: [0][500/17702]	Batch Time 0.350 (0.355)	Data Load Time 0.000 (0.001)	Loss 4.7625 (5.5699)	Top-5 Accuracy 53.388 (45.513)
# Epoch: [0][600/17702]	Batch Time 0.341 (0.355)	Data Load Time 0.000 (0.001)	Loss 4.7142 (5.4502)	Top-5 Accuracy 56.948 (47.098)
# Epoch: [0][700/17702]	Batch Time 0.336 (0.354)	Data Load Time 0.000 (0.001)	Loss 4.6704 (5.3507)	Top-5 Accuracy 60.174 (48.351)
# Epoch: [0][800/17702]	Batch Time 0.351 (0.354)	Data Load Time 0.000 (0.001)	Loss 5.0005 (5.2688)	Top-5 Accuracy 52.957 (49.432)
# Epoch: [0][900/17702]	Batch Time 0.364 (0.353)	Data Load Time 0.000 (0.000)	Loss 4.6985 (5.1953)	Top-5 Accuracy 58.356 (50.362)
# Epoch: [0][1000/17702]	Batch Time 0.370 (0.353)	Data Load Time 0.000 (0.000)	Loss 4.4734 (5.1327)	Top-5 Accuracy 60.995 (51.188)
# Epoch: [0][1100/17702]	Batch Time 0.371 (0.353)	Data Load Time 0.000 (0.000)	Loss 4.8599 (5.0747)	Top-5 Accuracy 53.922 (51.928)
# Epoch: [0][1200/17702]	Batch Time 0.363 (0.353)	Data Load Time 0.000 (0.000)	Loss 4.2469 (5.0217)	Top-5 Accuracy 61.828 (52.597)
# Epoch: [0][1300/17702]	Batch Time 0.346 (0.353)	Data Load Time 0.000 (0.000)	Loss 4.5398 (4.9755)	Top-5 Accuracy 55.053 (53.173)
# Epoch: [0][1400/17702]	Batch Time 0.351 (0.353)	Data Load Time 0.000 (0.000)	Loss 4.2653 (4.9330)	Top-5 Accuracy 61.749 (53.721)
# Epoch: [0][1500/17702]	Batch Time 0.350 (0.353)	Data Load Time 0.000 (0.000)	Loss 4.1649 (4.8953)	Top-5 Accuracy 62.295 (54.229)
# Epoch: [0][1600/17702]	Batch Time 0.356 (0.353)	Data Load Time 0.000 (0.000)	Loss 4.3549 (4.8613)	Top-5 Accuracy 62.670 (54.662)
# Epoch: [0][1700/17702]	Batch Time 0.356 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.2398 (4.8289)	Top-5 Accuracy 63.102 (55.086)
# Epoch: [0][1800/17702]	Batch Time 0.341 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.2832 (4.7980)	Top-5 Accuracy 62.602 (55.486)
# Epoch: [0][1900/17702]	Batch Time 0.339 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.2128 (4.7692)	Top-5 Accuracy 64.011 (55.855)
# Epoch: [0][2000/17702]	Batch Time 0.349 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.3300 (4.7413)	Top-5 Accuracy 62.534 (56.204)
# Epoch: [0][2100/17702]	Batch Time 0.360 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.4920 (4.7163)	Top-5 Accuracy 61.680 (56.539)
# Epoch: [0][2200/17702]	Batch Time 0.348 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.1228 (4.6930)	Top-5 Accuracy 64.706 (56.835)
# Epoch: [0][2300/17702]	Batch Time 0.347 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.9748 (4.6702)	Top-5 Accuracy 65.241 (57.123)
# Epoch: [0][2400/17702]	Batch Time 0.357 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.2944 (4.6492)	Top-5 Accuracy 60.109 (57.403)
# Epoch: [0][2500/17702]	Batch Time 0.360 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.2336 (4.6286)	Top-5 Accuracy 62.924 (57.671)
# Epoch: [0][2600/17702]	Batch Time 0.338 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.3194 (4.6088)	Top-5 Accuracy 62.571 (57.912)
# Epoch: [0][2700/17702]	Batch Time 0.352 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.8596 (4.5903)	Top-5 Accuracy 66.484 (58.160)
# Epoch: [0][2800/17702]	Batch Time 0.337 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.1469 (4.5731)	Top-5 Accuracy 64.489 (58.370)
# Epoch: [0][2900/17702]	Batch Time 0.338 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.9357 (4.5556)	Top-5 Accuracy 64.571 (58.588)
# Epoch: [0][3000/17702]	Batch Time 0.353 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.2091 (4.5381)	Top-5 Accuracy 63.912 (58.815)
# Epoch: [0][3100/17702]	Batch Time 0.343 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.8466 (4.5222)	Top-5 Accuracy 69.143 (59.012)
# Epoch: [0][3200/17702]	Batch Time 0.336 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.9827 (4.5061)	Top-5 Accuracy 68.012 (59.218)
# Epoch: [0][3300/17702]	Batch Time 0.344 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.9256 (4.4908)	Top-5 Accuracy 66.574 (59.410)
# Epoch: [0][3400/17702]	Batch Time 0.340 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.1199 (4.4764)	Top-5 Accuracy 62.570 (59.597)
# Epoch: [0][3500/17702]	Batch Time 0.356 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.1528 (4.4632)	Top-5 Accuracy 62.944 (59.772)
# Epoch: [0][3600/17702]	Batch Time 0.341 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.6621 (4.4495)	Top-5 Accuracy 70.170 (59.948)
# Epoch: [0][3700/17702]	Batch Time 0.346 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.9073 (4.4370)	Top-5 Accuracy 67.318 (60.104)
# Epoch: [0][3800/17702]	Batch Time 0.344 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.9996 (4.4244)	Top-5 Accuracy 66.942 (60.272)
# Epoch: [0][3900/17702]	Batch Time 0.375 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.9071 (4.4126)	Top-5 Accuracy 67.092 (60.415)
# Epoch: [0][4000/17702]	Batch Time 0.334 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.8325 (4.4010)	Top-5 Accuracy 65.789 (60.561)
# Epoch: [0][4100/17702]	Batch Time 0.359 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.9429 (4.3897)	Top-5 Accuracy 65.963 (60.705)
# Epoch: [0][4200/17702]	Batch Time 0.355 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.7305 (4.3786)	Top-5 Accuracy 69.613 (60.843)
# Epoch: [0][4300/17702]	Batch Time 0.357 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.8092 (4.3686)	Top-5 Accuracy 66.571 (60.968)
# Epoch: [0][4400/17702]	Batch Time 0.352 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.6540 (4.3580)	Top-5 Accuracy 71.200 (61.107)
# Epoch: [0][4500/17702]	Batch Time 0.351 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.3676 (4.3483)	Top-5 Accuracy 74.084 (61.229)
# Epoch: [0][4600/17702]	Batch Time 0.354 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.6199 (4.3393)	Top-5 Accuracy 73.656 (61.345)
# Epoch: [0][4700/17702]	Batch Time 0.353 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.7507 (4.3301)	Top-5 Accuracy 67.297 (61.463)
# Epoch: [0][4800/17702]	Batch Time 0.351 (0.351)	Data Load Time 0.000 (0.000)	Loss 4.0691 (4.3208)	Top-5 Accuracy 66.667 (61.582)
# Epoch: [0][4900/17702]	Batch Time 0.365 (0.351)	Data Load Time 0.000 (0.000)	Loss 4.0791 (4.3116)	Top-5 Accuracy 65.482 (61.699)
# Epoch: [0][5000/17702]	Batch Time 0.331 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.7530 (4.3027)	Top-5 Accuracy 69.006 (61.813)
# Epoch: [0][5100/17702]	Batch Time 0.352 (0.351)	Data Load Time 0.000 (0.000)	Loss 4.1473 (4.2951)	Top-5 Accuracy 63.920 (61.910)
# Epoch: [0][5200/17702]	Batch Time 0.343 (0.351)	Data Load Time 0.000 (0.000)	Loss 4.0971 (4.2865)	Top-5 Accuracy 63.662 (62.015)
# Epoch: [0][5300/17702]	Batch Time 0.346 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.6589 (4.2786)	Top-5 Accuracy 68.649 (62.115)
# Epoch: [0][5400/17702]	Batch Time 0.363 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.9536 (4.2707)	Top-5 Accuracy 65.464 (62.213)
# Epoch: [0][5500/17702]	Batch Time 0.356 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.9818 (4.2634)	Top-5 Accuracy 64.187 (62.305)
# Epoch: [0][5600/17702]	Batch Time 0.362 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.9260 (4.2562)	Top-5 Accuracy 68.146 (62.398)
# Epoch: [0][5700/17702]	Batch Time 0.360 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.
# Validation: [600/782]	Batch Time 0.267 (0.261)	Loss 3.2204 (3.4172)	Top-5 Accuracy 73.913 (72.951)
# Validation: [700/782]	Batch Time 0.260 (0.261)	Loss 3.3021 (3.4125)	Top-5 Accuracy 74.725 (73.016)
#
#  * LOSS - 3.414, TOP-5 ACCURACY - 73.007, BLEU-4 - 0.20026115980658207
#
# Epoch: [1][0/17702]	Batch Time 0.549 (0.549)	Data Load Time 0.158 (0.158)	Loss 3.6534 (3.6534)	Top-5 Accuracy 70.027 (70.027)
# Epoch: [1][100/17702]	Batch Time 0.349 (0.352)	Data Load Time 0.000 (0.002)	Loss 3.4164 (3.4762)	Top-5 Accuracy 72.678 (72.308)
# Epoch: [1][200/17702]	Batch Time 0.355 (0.352)	Data Load Time 0.000 (0.001)	Loss 3.6246 (3.4883)	Top-5 Accuracy 68.451 (72.181)
# Epoch: [1][300/17702]	Batch Time 0.348 (0.352)	Data Load Time 0.000 (0.001)	Loss 3.4498 (3.4862)	Top-5 Accuracy 74.317 (72.197)
# Epoch: [1][400/17702]	Batch Time 0.358 (0.352)	Data Load Time 0.000 (0.001)	Loss 3.3528 (3.4846)	Top-5 Accuracy 73.643 (72.214)
# Epoch: [1][500/17702]	Batch Time 0.349 (0.352)	Data Load Time 0.000 (0.001)	Loss 3.3120 (3.4890)	Top-5 Accuracy 72.603 (72.144)
# Epoch: [1][600/17702]	Batch Time 0.353 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.5884 (3.4914)	Top-5 Accuracy 69.648 (72.115)
# Epoch: [1][700/17702]	Batch Time 0.345 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.5457 (3.4921)	Top-5 Accuracy 73.164 (72.092)
# Epoch: [1][800/17702]	Batch Time 0.372 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.3840 (3.4933)	Top-5 Accuracy 73.766 (72.084)
# Epoch: [1][900/17702]	Batch Time 0.339 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.7121 (3.4936)	Top-5 Accuracy 67.867 (72.067)
# Epoch: [1][1000/17702]	Batch Time 0.347 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.4002 (3.4944)	Top-5 Accuracy 72.973 (72.059)
# Epoch: [1][1100/17702]	Batch Time 0.353 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.3112 (3.4911)	Top-5 Accuracy 72.603 (72.084)
# Epoch: [1][1200/17702]	Batch Time 0.352 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.5720 (3.4929)	Top-5 Accuracy 70.255 (72.043)
# Epoch: [1][1300/17702]	Batch Time 0.368 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.5793 (3.4923)	Top-5 Accuracy 70.235 (72.059)
# Epoch: [1][1400/17702]	Batch Time 0.346 (0.352)	Data Load Time 0.000 (0.000)	Loss 3.6261 (3.4922)	Top-5 Accuracy 74.302 (72.052)
# Epoch: [1][1500/17702]	Batch Time 0.345 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.3876 (3.4908)	Top-5 Accuracy 71.978 (72.057)
# Epoch: [1][1600/17702]	Batch Time 0.370 (0.352)	Data Load Time 0.000 (0.000)	Loss 4.0019 (3.4894)	Top-5 Accuracy 65.649 (72.081)
# Epoch: [1][1700/17702]	Batch Time 0.345 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.5558 (3.4881)	Top-5 Accuracy 70.520 (72.105)
# Epoch: [1][1800/17702]	Batch Time 0.377 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.8957 (3.4888)	Top-5 Accuracy 67.532 (72.102)
# Epoch: [1][1900/17702]	Batch Time 0.344 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.4296 (3.4885)	Top-5 Accuracy 73.554 (72.104)
# Epoch: [1][2000/17702]	Batch Time 0.341 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.
(0.351)	Data Load Time 0.000 (0.000)	Loss 3.3404 (3.1249)	Top-5 Accuracy 73.816 (77.071)
# Epoch: [9][16400/17702]	Batch Time 0.342 (0.350)	Data Load Time 0.000 (0.000)	Loss 2.9746 (3.1252)	Top-5 Accuracy 77.437 (77.068)
# Epoch: [9][16500/17702]	Batch Time 0.369 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.3564 (3.1254)	Top-5 Accuracy 70.483 (77.066)
# Epoch: [9][16600/17702]	Batch Time 0.358 (0.351)	Data Load Time 0.000 (0.000)	Loss 2.8161 (3.1257)	Top-5 Accuracy 82.895 (77.065)
# Epoch: [9][16700/17702]	Batch Time 0.355 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.3245 (3.1258)	Top-5 Accuracy 75.414 (77.065)
# Epoch: [9][16800/17702]	Batch Time 0.342 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.0946 (3.1262)	Top-5 Accuracy 76.177 (77.059)
# Epoch: [9][16900/17702]	Batch Time 0.352 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.1712 (3.1263)	Top-5 Accuracy 75.070 (77.057)
# Epoch: [9][17000/17702]	Batch Time 0.348 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.2920 (3.1265)	Top-5 Accuracy 74.033 (77.056)
# Epoch: [9][17100/17702]	Batch Time 0.430 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.3325 (3.1268)	Top-5 Accuracy 73.945 (77.053)
# Epoch: [9][17200/17702]	Batch Time 0.342 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.1201 (3.1269)	Top-5 Accuracy 78.814 (77.050)
# Epoch: [9][17300/17702]	Batch Time 0.349 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.1359 (3.1273)	Top-5 Accuracy 76.862 (77.045)
# Epoch: [9][17400/17702]	Batch Time 0.342 (0.351)	Data Load Time 0.000 (0.000)	Loss 2.9175 (3.1274)	Top-5 Accuracy 80.501 (77.044)
# Epoch: [9][17500/17702]	Batch Time 0.334 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.2915 (3.1277)	Top-5 Accuracy 75.793 (77.041)
# Epoch: [9][17600/17702]	Batch Time 0.344 (0.351)	Data Load Time 0.000 (0.000)	Loss 3.1362 (3.1276)	Top-5 Accuracy 76.554 (77.042)
# Epoch: [9][17700/17702]	Batch Time 0.344 (0.351)	Data Load Time 0.000 (0.000)	Loss 2.9886 (3.1277)	Top-5 Accuracy 79.189 (77.041)
# Validation: [0/782]	Batch Time 0.610 (0.610)	Loss 3.4641 (3.4641)	Top-5 Accuracy 72.626 (72.626)
# Validation: [100/782]	Batch Time 0.257 (0.264)	Loss 3.4188 (3.2349)	Top-5 Accuracy 73.199 (75.841)
# Validation: [200/782]	Batch Time 0.261 (0.262)	Loss 3.2634 (3.2117)	Top-5 Accuracy 75.698 (76.129)
# Validation: [300/782]	Batch Time 0.262 (0.262)	Loss 3.4108 (3.2128)	Top-5 Accuracy 75.000 (76.120)
# Validation: [400/782]	Batch Time 0.258 (0.261)	Loss 3.2522 (3.2093)	Top-5 Accuracy 77.635 (76.174)
# Validation: [500/782]	Batch Time 0.267 (0.261)	Loss 3.7588 (3.2065)	Top-5 Accuracy 70.635 (76.226)
# Validation: [600/782]	Batch Time 0.266 (0.261)	Loss 2.9739 (3.2043)	Top-5 Accuracy 79.124 (76.257)
# Validation: [700/782]	Batch Time 0.261 (0.261)	Loss 2.8138 (3.2054)	Top-5 Accuracy 83.754 (76.244)
#
#  * LOSS - 3.206, TOP-5 ACCURACY - 76.262, BLEU-4 - 0.2292431787310961
#
#
# Epochs since last improvement: 1
